# %%
"""
Team Nova:
Arpit Palo
Arun Kumar
Nisarg Gupta
Omkar Kanade
"""

# Code to merge temperature data with greenhouse gas data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temp_df = pd.read_csv('Merged_Temp.csv')
temp_df = temp_df.drop(['Unnamed: 0'], axis=1)
gas_df = pd.read_csv('GHG_Data/ghg_merged.csv')
gas_df = gas_df.drop(['Unnamed: 0'], axis=1)

# %%
temp_df.head()
# Out:
#   CountryCode  Month  Year       tmpf       dwpf         mslp      sknt  \
# 0          AE      1  1998  65.458763  56.045068  1018.097921  6.545845
# 1          AE      2  1998  68.562623  54.735838  1016.853637  7.247619
# 2          AE      3  1998  75.013693  57.406706  1014.256000  7.266628
# 3          AE      4  1998  82.306805  58.289718  1010.446900  7.312550
# 4          AE      5  1998  90.308306  60.247751  1006.463388  6.752338
#
#         feel       relh  ice_accretion_6hr  p01i
# 0  65.486669  73.471497                NaN   NaN
# 1  68.508641  64.828713                NaN   NaN
# 2  74.756180  59.583567                NaN   NaN
# 3  82.352514  49.981098                NaN   NaN
# 4  91.290631  42.404219                NaN   NaN

# %%
gas_df.head()
# Out:
#    Year  Month CountryCode  Methane Levels  CO2 Levels   NO Levels
# 0  1960      1          NZ     1206.146098  315.252611  291.489521
# 1  1960      2          NZ     1202.801309  315.188733  291.405445
# 2  1960      3          NZ     1202.789472  315.209984  291.271675
# 3  1960      4          NZ     1205.792690  315.272289  291.194145
# 4  1960      5          NZ     1210.439217  315.420102  291.190428

# %%
merged_df = pd.merge(temp_df, gas_df, on=['CountryCode', 'Month', 'Year'])

# %%
merged_df
# Out:
#       CountryCode  Month  Year       tmpf       dwpf         mslp      sknt  \
# 0              AE      1  1998  65.458763  56.045068  1018.097921  6.545845
# 1              AE      2  1998  68.562623  54.735838  1016.853637  7.247619
# 2              AE      3  1998  75.013693  57.406706  1014.256000  7.266628
# 3              AE      4  1998  82.306805  58.289718  1010.446900  7.312550
# 4              AE      5  1998  90.308306  60.247751  1006.463388  6.752338
# ...           ...    ...   ...        ...        ...          ...       ...
# 85796          ZW      8  1980  64.313430  40.553678          NaN  7.837230
# 85797          ZW      9  1980  70.603867  48.065622          NaN  7.750000
# 85798          ZW     10  1980  74.283110  50.029111          NaN  7.964381
# 85799          ZW     11  1980  75.160548  58.477686          NaN  6.815789
# 85800          ZW     12  1980  73.573793  61.692597          NaN  6.568493
#
# ...

# %%
years = merged_df['Year'].unique()
years = np.sort(years)
years
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])

# %%
# merged_df.to_csv('merged_temp_ghg.csv')

# %%
merged_df[merged_df['CountryCode'] == 'IN'].corr()
# Out:
#                       Month      Year      tmpf      dwpf      mslp      sknt  \
# Month              1.000000 -0.002403 -0.004694  0.346107 -0.021807 -0.247085
# Year              -0.002403  1.000000  0.064743  0.072814 -0.000706 -0.100006
# tmpf              -0.004694  0.064743  1.000000  0.689924 -0.880230  0.739489
# dwpf               0.346107  0.072814  0.689924  1.000000 -0.845096  0.592966
# mslp              -0.021807 -0.000706 -0.880230 -0.845096  1.000000 -0.838208
# sknt              -0.247085 -0.100006  0.739489  0.592966 -0.838208  1.000000
# feel               0.066434  0.068488  0.972839  0.825295 -0.949988  0.779213
# relh               0.478004  0.020866 -0.067720  0.672119 -0.275158  0.064134
# ice_accretion_6hr       NaN       NaN       NaN       NaN       NaN       NaN
# p01i               0.097627  0.034310 -0.104096 -0.087289  0.065514 -0.064940
# Methane Levels    -0.006629  0.948554 -0.000854 -0.003449  0.076977 -0.185027
# ...

# %%
# plt.plot(merged_df[])
agg_df = merged_df.groupby('Year').max()
# agg_df
# Out:
# /var/folders/c3/m44j2qx97f9bdyhx6dfy1p240000gn/T/ipykernel_99434/1535369960.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   agg_df = merged_df.groupby('Year').max()

# %%
# agg_df.corr()

# %%
corrs = {}
for month in range(1, 13):
    month_df = merged_df[merged_df['Month'] == month]
    corrs[month] = (month_df.corr()[['CO2 Levels', 'Year']].loc['tmpf'])

# %%
corrs
# Out:
# {1: CO2 Levels    0.031020
#  Year          0.107439
#  Name: tmpf, dtype: float64,
#  2: CO2 Levels    0.032914
#  Year          0.102441
#  Name: tmpf, dtype: float64,
#  3: CO2 Levels    0.048769
#  Year          0.105227
#  Name: tmpf, dtype: float64,
#  4: CO2 Levels    0.072265
#  Year          0.107980
#  Name: tmpf, dtype: float64,
#  5: CO2 Levels    0.092608
#  Year          0.098393
#  Name: tmpf, dtype: float64,
#  6: CO2 Levels    0.108421
#  Year          0.089154
#  Name: tmpf, dtype: float64,
#  7: CO2 Levels    0.103354
#  Year          0.083433
#  Name: tmpf, dtype: float64,
#  8: CO2 Levels    0.091237
#  Year          0.074953
#  Name: tmpf, dtype: float64,
#  9: CO2 Levels    0.101288
#  Year          0.086192
#  Name: tmpf, dtype: float64,
#  10: CO2 Levels    0.089037
#  Year          0.100893
#  Name: tmpf, dtype: float64,
#  11: CO2 Levels    0.065729
#  Year          0.112815
#  Name: tmpf, dtype: float64,
#  12: CO2 Levels    0.038653
# ...
